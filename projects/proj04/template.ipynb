# %% [markdown]
# # Your Title Here
#
# **Name(s)**: Yonghao Wang
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# from dsc80_utils import * # Feel free to uncomment and use this.

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
from pathlib import Path
import pandas as pd
import plotly.express as px

path = Path("2018_LoL_esports_match_data_from_OraclesElixir.csv")
df = pd.read_csv(path)

df["gamelength_min"] = df["gamelength"] / 60

fig = px.histogram(
    df,
    x="gamelength_min",
    title="Distribution of Game Length (2018 LoL Esports)",
    labels={"gamelength_min": "Game Length (minutes)"}
)
fig.show()

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
